# %%
import pandas as pd

# %%
data=pd.read_csv('C:\\Clg\\TekWorks\\week-7\\Day-13\\Insurance_Test.csv')
data.head()
# Out:
#    Age  InsuranceCost
# 0   22           2500
# 1   25           2800
# 2   28           3200
# 3   30           3500
# 4   35           4200

# %%
x=data[['Age']]
y=data['InsuranceCost']

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.scatter(x='Age',y='InsuranceCost',data=data)
m,c=np.polyfit(data['Age'],data['InsuranceCost'],1)
plt.plot(x,m*data['Age']+c)

# %%
import seaborn as sns
sns.regplot(x='Age',y='InsuranceCost',data=data)
# Out:
# <Axes: xlabel='Age', ylabel='InsuranceCost'>

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(pd.DataFrame({'Age':[30]}))
